# %%
# Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Loading the data
df = pd.read_csv('Bengaluru_House_Data.csv')

# %%
# Checking the data
df.head(5)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
# Checking number of rows and columns of the data
df.shape
# Out:
# (13320, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
# Gettting more information about the data
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
# Missing values in the data
df.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
# Getting information about the number of categories in each column
df.nunique()
# Out:
# area_type          4
# availability      81
# location        1305
# size              31
# society         2688
# total_sqft      2117
# bath              19
# balcony            4
# price           1994
# dtype: int64

# %%
df[df['location']=='Old Airport Road']
# Out:
#                   area_type   availability          location       size  \
# 6      Super built-up  Area         18-May  Old Airport Road      4 BHK
# 765          Built-up  Area  Ready To Move  Old Airport Road      3 BHK
# 1302   Super built-up  Area         18-Dec  Old Airport Road      4 BHK
# 1312   Super built-up  Area  Ready To Move  Old Airport Road      2 BHK
# 1771   Super built-up  Area         18-May  Old Airport Road      4 BHK
# 1828   Super built-up  Area         18-Dec  Old Airport Road      4 BHK
# 1889   Super built-up  Area         18-May  Old Airport Road      4 BHK
# 2818   Super built-up  Area         18-May  Old Airport Road      2 BHK
# 3203   Super built-up  Area  Ready To Move  Old Airport Road      2 BHK
# 3757         Built-up  Area  Ready To Move  Old Airport Road      3 BHK
# 3840   Super built-up  Area  Ready To Move  Old Airport Road      2 BHK
# 3861   Super built-up  Area         18-Dec  Old Airport Road      4 BHK
# ...

# %%
# Getting information about the area_type column
df['area_type'].value_counts()
# Out:
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64

# %%
df['availability'].value_counts()
# Out:
# Ready To Move    10581
# 18-Dec             307
# 18-May             295
# 18-Apr             271
# 18-Aug             200
#                  ...
# 16-Jan               1
# 15-Jun               1
# 14-Jul               1
# 15-Aug               1
# 15-Dec               1
# Name: availability, Length: 81, dtype: int64

# %%
df['location'].value_counts()
# Out:
# Whitefield               540
# Sarjapur  Road           399
# Electronic City          302
# Kanakpura Road           273
# Thanisandra              234
#                         ...
# Narayanappa Layout         1
# Thavarekere                1
# kamanahalli main road      1
# Jp nagar 8th Phase .       1
# Sundara Nagar              1
# Name: location, Length: 1305, dtype: int64

# %%
df['size'].value_counts()
# Out:
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 10 BHK           2
# 11 BHK           2
# 11 Bedroom       2
# 12 Bedroom       1
# 27 BHK           1
# 13 BHK           1
# 14 BHK           1
# 16 BHK           1
# 43 Bedroom       1
# 18 Bedroom       1
# 19 BHK           1
# Name: size, dtype: int64

# %%
df['bath'].value_counts()
# Out:
# 2.0     6908
# 3.0     3286
# 4.0     1226
# 1.0      788
# 5.0      524
# 6.0      273
# 7.0      102
# 8.0       64
# 9.0       43
# 10.0      13
# 12.0       7
# 11.0       3
# 13.0       3
# 16.0       2
# 14.0       1
# 40.0       1
# 18.0       1
# 27.0       1
# 15.0       1
# Name: bath, dtype: int64

# %%
df['balcony'].value_counts()
# Out:
# 2.0    5113
# 1.0    4897
# 3.0    1672
# 0.0    1029
# Name: balcony, dtype: int64

# %%
df['price'].hist(figsize=(5,5), bins=30)
# Out:
# <AxesSubplot:>

# %%
df.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.drop(['society', 'availability'], axis=1,inplace=True)

# %%
df.head()
# Out:
#               area_type                  location       size total_sqft  bath  \
# 0  Super built-up  Area  Electronic City Phase II      2 BHK       1056   2.0
# 1            Plot  Area          Chikka Tirupathi  4 Bedroom       2600   5.0
# 2        Built-up  Area               Uttarahalli      3 BHK       1440   2.0
# 3  Super built-up  Area        Lingadheeranahalli      3 BHK       1521   3.0
# 4  Super built-up  Area                  Kothanur      2 BHK       1200   2.0
#
#    balcony   price
# 0      1.0   39.07
# 1      3.0  120.00
# 2      3.0   62.00
# 3      1.0   95.00
# 4      1.0   51.00

# %%
dummies=pd.get_dummies(df['area_type'])
dummies
# Out:
#        Built-up  Area  Carpet  Area  Plot  Area  Super built-up  Area
# 0                   0             0           0                     1
# 1                   0             0           1                     0
# 2                   1             0           0                     0
# 3                   0             0           0                     1
# 4                   0             0           0                     1
# ...               ...           ...         ...                   ...
# 13315               1             0           0                     0
# 13316               0             0           0                     1
# 13317               1             0           0                     0
# 13318               0             0           0                     1
# 13319               0             0           0                     1
#
# [13320 rows x 4 columns]

# %%
df= pd.concat([df, dummies], axis=1)

# %%
df.head()
# Out:
#               area_type                  location       size total_sqft  bath  \
# 0  Super built-up  Area  Electronic City Phase II      2 BHK       1056   2.0
# 1            Plot  Area          Chikka Tirupathi  4 Bedroom       2600   5.0
# 2        Built-up  Area               Uttarahalli      3 BHK       1440   2.0
# 3  Super built-up  Area        Lingadheeranahalli      3 BHK       1521   3.0
# 4  Super built-up  Area                  Kothanur      2 BHK       1200   2.0
#
#    balcony   price  Built-up  Area  Carpet  Area  Plot  Area  \
# 0      1.0   39.07               0             0           0
# 1      3.0  120.00               0             0           1
# 2      3.0   62.00               1             0           0
# 3      1.0   95.00               0             0           0
# 4      1.0   51.00               0             0           0
#
#    Super built-up  Area
# 0                     1
# 1                     0
# 2                     0
# 3                     1
# ...

# %%
df.columns
# Out:
# Index(['area_type', 'location', 'size', 'total_sqft', 'bath', 'balcony',
#        'price', 'Built-up  Area', 'Carpet  Area', 'Plot  Area',
#        'Super built-up  Area'],
#       dtype='object')

# %%
df.drop(['area_type', 'Super built-up  Area'], axis=1,inplace=True)

# %%
df.head()
# Out:
#                    location       size total_sqft  bath  balcony   price  \
# 0  Electronic City Phase II      2 BHK       1056   2.0      1.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0      3.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0      3.0   62.00
# 3        Lingadheeranahalli      3 BHK       1521   3.0      1.0   95.00
# 4                  Kothanur      2 BHK       1200   2.0      1.0   51.00
#
#    Built-up  Area  Carpet  Area  Plot  Area
# 0               0             0           0
# 1               0             0           1
# 2               1             0           0
# 3               0             0           0
# 4               0             0           0
